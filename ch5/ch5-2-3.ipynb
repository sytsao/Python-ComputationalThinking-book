# %%
all(['Mary', 66.45,  78])
# Out:
# True

# %%
all(['', 66.45,  78])
# Out:
# False

# %%
all([False, 66.45, 78])
# Out:
# False

# %%
all([3,2,1,0])
# Out:
# False

# %%
all([])
# Out:
# True

# %%
all(())
# Out:
# True

# %%
any(['Mary', 66.45, 78])
# Out:
# True

# %%
any(['','',''])
# Out:
# False

# %%
any([False, False, False])
# Out:
# False

# %%
any([0,0,0])
# Out:
# False

# %%
any([' ', 66.45, 78])
# Out:
# True

# %%
any(['Mary' , False, 78])
# Out:
# True

# %%
any(['Mary', 66.45,0])
# Out:
# True

# %%
any([])
# Out:
# False

# %%
any(())
# Out:
# False
